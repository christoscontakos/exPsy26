# %%
import pandas as pd

# %%
a = [3, 4, 78, 6]
b = [43, 42, 178, 76]
c = [38, 45, 728, 46]

# %%
arla = pd.DataFrame({'a': a,
                   'b': b,
                   'c': c})

# %%
type(arla)
# Out:
# pandas.DataFrame

# %%
arla
# Out:
#     a    b    c    row_mean
# 0   3   43   38   28.000000
# 1   4   42   45   30.333333
# 2  78  178  728  328.000000
# 3   6   76   46   42.666667

# %%
d = arla['a']

# %%
type(d)
# Out:
# pandas.Series

# %%
arla["row_mean"] = arla.mean(axis=1)

# %%
df = pd.read_csv('Stroop-raw-over-the-years.csv')

# %%
df
# Out:
# 0       5.0050
# 1       5.3300
# 2       4.5250
# 3       5.9575
# 4       6.8175
#         ...
# 200     6.6675
# 201     8.4575
# 202     7.1000
# 203     6.6700
# 204    10.8000
# Length: 205, dtype: float64

# %%
df['column_mean'] = df=df.drop(['Year'],axis=1).mean(axis=1)

# %%
df
# Out:
# 0       5.0050
# 1       5.3300
# 2       4.5250
# 3       5.9575
# 4       6.8175
#         ...
# 200     6.6675
# 201     8.4575
# 202     7.1000
# 203     6.6700
# 204    10.8000
# Length: 205, dtype: float64

# %%
df
# Out:
# 0       5.0050
# 1       5.3300
# 2       4.5250
# 3       5.9575
# 4       6.8175
#         ...
# 200     6.6675
# 201     8.4575
# 202     7.1000
# 203     6.6700
# 204    10.8000
# Length: 205, dtype: float64
