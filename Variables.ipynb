# %% [markdown]
# # Variables and variable types
#
# ## "Regular" variables
#
# 1. strings
# 1. integers
# 1. floats
#
# ## "Collection" variables
#
# 1. tuples
# 1. lists
# 1. sets
# 1. dictionaries
#
# From https://www.w3schools.com:
#
# - **Strings** are for storing text
# - **Integers** are for storing whole numbers, positive or negative (such as 123 or -456), without decimals.
# - **Floats** are for storing positive and negative numbers with a decimal point, like 35.3, or -2.34
# - **Lists** are collections which are ordered and changeable. Allows duplicate members.
# - **Tuples** are collections which are ordered and unchangeable. Allows duplicate members.
# - **Sets** are collections which are unordered, "unchangeable", and unindexed. No duplicate members.
# - **Dictionaries** are collections which are ordered and changeable. No duplicate members.

# %% [markdown]
# ## Strings

# %%
string = 'Neptune'

# %% [markdown]
# ## Integers

# %%
integer = 7

# %% [markdown]
# ## Floats

# %%
floatingPoint = 3.14

# %% [markdown]
# ## Lists

# %%
myList = ['eggs', 'bread', 'milk']
myList[2] = 5
print(myList)

myList = [string, integer, floatingPoint]
print(myList)
# Out:
# ['eggs', 'bread', 5]
# ['Neptune', 7, 3.14]

# %% [markdown]
# ## Tuples

# %%
myTuple = ('apples', 'pears', 'bananas')
print(myTuple[1])
# Out:
# pears

# %% [markdown]
# ## Sets

# %%
newList = [4, 4, 7, 19, 21, 'I am a string', 7.23]
mySet = set(newList)
mySet
# Out:
# {19, 21, 4, 7, 7.23, 'I am a string'}

# %% [markdown]
# ## Dictionaries

# %%
myDictionary = {'name': 'Neptune',
                'species': 'cat',
                'likes': 'Pony',
                'dislikes': 'ice',
                'age': 3}

print(myDictionary['name'] + ' is ' + str(myDictionary['age']) + ' years old.')
# Out:
# Neptune is 3 years old.

# %%
items = ['grapes', 'skyr', ['salt', 'pepper', ['cumin', 'paprika']], 'rice']
number = [1, 2, 7, 3]
priority = ['high', 'high', 'low', 'high']

# %%
shopping = {'items': items,
            'number': number,
            'priority': priority}

# %%
shopping['items']
# Out:
# ['grapes', 'skyr', ['salt', 'pepper', ['cumin', 'paprika']], 'rice']

# %%
shopping['items'][2]
# Out:
# ['salt', 'pepper', ['cumin', 'paprika']]

# %%
shopping['items'][2][2]
# Out:
# ['cumin', 'paprika']

# %%
shopping['items'][2][2][0]
# Out:
# 'cumin'
